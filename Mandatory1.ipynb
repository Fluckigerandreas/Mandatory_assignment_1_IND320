# %% [markdown]
# Link to github repository: https://github.com/Fluckigerandreas/Mandatory_assignment_1_IND320.git
#
# Link to streamlit app: https://fluckigerandreas.streamlit.app

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Read CSV
df = pd.read_csv("open-meteo-subset.csv")

# 2. Print info
print(df.info())
print(df.head())

# 3. Plot each column separately
for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        plt.figure(figsize=(8, 4))
        plt.plot(df[column])
        plt.title(f"{column} over time")
        plt.xlabel("Index")
        plt.ylabel(column)
        plt.grid(True)
        plt.show()

# 4. Plot all numeric columns together (normalized)
numeric_cols = df.select_dtypes(include='number').columns
df_numeric = df[numeric_cols]
df_normalized = (df_numeric - df_numeric.min()) / (df_numeric.max() - df_numeric.min())

plt.figure(figsize=(10, 6))
for column in df_normalized.columns:
    plt.plot(df_normalized[column], label=column)

plt.title("All numeric columns (normalized to [0,1])")
plt.xlabel("Index")
plt.ylabel("Normalized values")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    8760 non-null   object
#  1   temperature_2m (°C)     8760 non-null   float64
#  2   precipitation (mm)      8760 non-null   float64
#  3   wind_speed_10m (m/s)    8760 non-null   float64
#  4   wind_gusts_10m (m/s)    8760 non-null   float64
#  5   wind_direction_10m (°)  8760 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 410.8+ KB
# None
#                time  temperature_2m (°C)  precipitation (mm)  \
# 0  2020-01-01T00:00                 -2.2                 0.1
# 1  2020-01-01T01:00                 -2.2                 0.0
# 2  2020-01-01T02:00                 -2.3                 0.0
# 3  2020-01-01T03:00                 -2.3                 0.0
# ...

# %% [markdown]
# Log and AI usage:

# %% [markdown]
# In this project, I focused on creating an interactive visualization of weather data using Python, Streamlit, and Altair, with the goal of exploring temporal patterns across multiple variables. One of the first challenges I encountered was working with an older Mac, which sometimes caused delays and memory constraints when handling larger datasets or running multiple plotting libraries simultaneously. In addition, I faced issues with dependencies and software versions that did not always work well together, causing import errors and module conflicts. Despite these hardware and system limitations, I was able to structure a workflow that allowed for efficient data loading, filtering, and plotting without overloading the system.
#
# For the initial exploratory analysis, I primarily used Matplotlib because it is the library I am most familiar with. Matplotlib allowed me to quickly plot each variable separately and to normalize multiple columns for combined visualizations. Its flexibility made it easy to create clear, readable plots and to experiment with different layouts, scales, and normalization techniques. However, I recognize that for more interactive and web-friendly plots, Plotly could be a better choice in the future, as it provides built-in zooming, panning, and hover tools that enhance user interactivity. The main issue with matplotlib became apparant with the last plot in the jupiter file.
#
# In developing the Page2.py, I had to make several design choices to balance usability and clarity. I decided to use Altair for plotting within Streamlit because of its declarative syntax, seamless integration, and ability to handle interactive features such as tooltips and color encoding for multiple variables. This is important because of the fact that I am colorblind. The app allows users to select individual weather variables or visualize all variables together and includes a slider to filter data by month. I also added a preprocessing step that converts the time column to a datetime format and extracts year-month periods. This facilitates intuitive filtering and ensures the plots accurately reflect temporal trends.
#
# During the development of this project, I also used AI-assisted coding tools (ChatGPT) to clarify errors, suggest improvements in data handling and plotting, and provide guidance on best practices for interactive visualizations. The AI support was used as a learning and advisory tool, while all code implementation, decisions, and final outputs were written, tested, and adapted independently. This ensured that the project reflects my own understanding and choices.
